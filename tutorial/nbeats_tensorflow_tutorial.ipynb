# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://github.com/flaviagiammarino/nbeats-tensorflow/tutorial/nbeats-tensorflow-tutorial.ipynb)

# %% [markdown]
# # N-BEATS TensorFlow Tutorial

# %% [markdown]
# **Paper:** Oreshkin, B. N., Carpov, D., Chapados, N., & Bengio, Y. (2019). N-BEATS: Neural basis expansion analysis for interpretable time series forecasting. [arXiv:1905.10437](https://arxiv.org/abs/1905.10437).
#
# **Data:** SILSO, World Data Center - Sunspot Number and Long-Term Solar Observations, Royal Observatory of Belgium, 1818 - 2021. https://wwwbis.sidc.be/silso/datafiles.
#
# **Code:** TensorFlow (Python) implementation of N-BEATS model for univariate time series forecasting. https://github.com/flaviagiammarino/nbeats-tensorflow.

# %% [markdown]
# ## 1. Set Up

# %% [markdown]
# Install the dependencies.

# %%
# !pip install pandas numpy tensorflow plotly optuna
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.19.5)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (2.7.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (4.4.1)
# Collecting optuna
#   Downloading optuna-2.10.0-py3-none-any.whl (308 kB)
#      |████████████████████████████████| 308 kB 4.5 MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (12.0.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.13.3)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.41.1)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.12.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.21.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (1.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (2.23.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (57.4.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (1.0.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (4.8.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly) (1.3.3)
# Collecting alembic
#   Downloading alembic-1.7.5-py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 27.1 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.62.3)
# Collecting colorlog
#   Downloading colorlog-6.6.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.26)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.1)
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Collecting cliff
#   Downloading cliff-3.9.0-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 3.7 MB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (3.13)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (2.4.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.1.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (5.4.0)
# Collecting Mako
#   Downloading Mako-1.1.5-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 2.2 MB/s
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.7.0-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 57.8 MB/s
# Collecting autopage>=0.4.0
#   Downloading autopage-0.4.0-py3-none-any.whl (20 kB)
# Collecting stevedore>=2.0.1
#   Downloading stevedore-3.5.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 5.6 MB/s
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.3.0-py3-none-any.whl (148 kB)
#      |████████████████████████████████| 148 kB 55.2 MB/s
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (2.4.0)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (21.2.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.6.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (2.0.1)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11136 sha256=98a9799f9aec6bf11a029463217e819d77084aabe1e94a56c7bdeceed64c63a9
#   Stored in directory: /root/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built pyperclip
# Installing collected packages: pyperclip, pbr, stevedore, Mako, cmd2, autopage, colorlog, cmaes, cliff, alembic, optuna
# Successfully installed Mako-1.1.5 alembic-1.7.5 autopage-0.4.0 cliff-3.9.0 cmaes-0.8.2 cmd2-2.3.0 colorlog-6.6.0 optuna-2.10.0 pbr-5.7.0 pyperclip-1.8.2 stevedore-3.5.0

# %% [markdown]
# Clone the repository.

# %%
# !pip install github-clone
# Out:
# Collecting github-clone
#   Downloading github_clone-1.2.0-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from github-clone) (2.23.0)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.7/dist-packages (from github-clone) (0.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->github-clone) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->github-clone) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->github-clone) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->github-clone) (1.24.3)
# Installing collected packages: github-clone
# Successfully installed github-clone-1.2.0

# %%
# !ghclone https://github.com/flaviagiammarino/nbeats-tensorflow/tree/main/nbeats_tensorflow
# Out:
# Cloning into 'nbeats_tensorflow'...
# done.

# %% [markdown]
# Import the libraries.

# %%
import optuna
import logging
import pandas as pd
import numpy as np
import tensorflow as tf
import plotly.graph_objects as go

# %%
from nbeats_tensorflow.model import NBeats

# %% [markdown]
# Set the logging level.

# %%
tf.get_logger().setLevel(logging.ERROR)
optuna.logging.set_verbosity(optuna.logging.INFO)

# %% [markdown]
# Fix the random seeds.

# %%
TENSORFLOW_SEED = 0
OPTUNA_SEED = 0

# %% [markdown]
# ## 2. Data

# %% [markdown]
# Download the data.

# %%
df = pd.read_csv('https://wdc-silso-daily-sunspot-number.s3.eu-west-2.amazonaws.com/SN_d_tot_V2.0.csv', sep=';', header=None, usecols=[0, 1, 2, 4], names=['year', 'month', 'day', 'y'])

# %%
df
# Out:
#        year  month  day    y
# 0      1818      1    1   -1
# 1      1818      1    2   -1
# 2      1818      1    3   -1
# 3      1818      1    4   -1
# 4      1818      1    5   -1
# ...     ...    ...  ...  ...
# 74444  2021     10   27  104
# 74445  2021     10   28  100
# 74446  2021     10   29   85
# 74447  2021     10   30   78
# 74448  2021     10   31   68
#
# [74449 rows x 4 columns]

# %% [markdown]
# Fill the missing values with zero.

# %%
df.loc[df['y'] == -1, 'y'] = 0

# %% [markdown]
# Generate the timestamps.

# %%
df['timestamp'] = pd.to_datetime(df['year'].astype(str) + '-' + df['month'].astype(str) + '-' + df['day'].astype(str))

# %% [markdown]
# Drop the unnecessary columns.

# %%
df = df[['timestamp', 'y']]

# %% [markdown]
# Downsample the data from daily to monthly.

# %%
df = df.set_index('timestamp').resample('M')['y'].mean().reset_index()

# %%
df
# Out:
#       timestamp          y
# 0    1818-01-31  15.000000
# 1    1818-02-28  18.714286
# 2    1818-03-31  19.129032
# 3    1818-04-30  40.266667
# 4    1818-05-31  71.354839
# ...         ...        ...
# 2441 2021-06-30  24.966667
# 2442 2021-07-31  34.387097
# 2443 2021-08-31  22.387097
# 2444 2021-09-30  51.500000
# 2445 2021-10-31  38.129032
#
# [2446 rows x 2 columns]

# %% [markdown]
# Plot the data.

# %%
layout = dict(
    width=800,
    height=400,
    plot_bgcolor='white',
    paper_bgcolor='white',
    margin=dict(t=40, b=20, l=20, r=20),
    xaxis=dict(
        type='date',
        nticks=20,
        tickfont=dict(
            color='#3a3a3a',
            size=10,
        ),
        linecolor='#d9d9d9',
        mirror=True,
        showgrid=False,
    ),
    yaxis=dict(
        tickfont=dict(
            color='#3a3a3a',
            size=10,
        ),
        linecolor='#d9d9d9',
        mirror=True,
        showgrid=False,
        zeroline=False,
    ),
)

data = go.Scatter(
    x=df['timestamp'],
    y=df['y'],
    mode='lines',
    line=dict(
        color='#b3b3b3',
        width=0.5
    )
)

fig = go.Figure(data=data, layout=layout)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8ca40d0c-354d-4c0e-8239-be3564fe5ae0" class="plotly-graph-div" style="height:400px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8ca40d0c-354d-4c0e-8239-be3564fe5ae0")) {
#                     Plotly.newPlot(
#                         '8ca40d0c-354d-4c0e-8239-be3564fe5ae0',
#                         [{"line": {"color": "#b3b3b3", "width": 0.5}, "mode": "lines", "type": "scatter", "x": ["1818-01-31T00:00:00", "1818-02-28T00:00:00", "1818-03-31T00:00:00", "1818-04-30T00:00:00", "1818-05-31T00:00:00", "1818-06-30T00:00:00", "1818-07-31T00:00:00", "1818-08-31T00:00:00", "1818-09-30T00:00:00", "1818-10-31T00:00:00", "1818-11-30T00:00:00", "1818-12-31T00:00:00", "1819-01-31T00:00:00", "1819-02-28T00:00:00", "1819-03-31T00:00:00", "1819-04-30T00:00:00", "1819-05-31T00:00:00", "1819-06-30T00:00:00", "1819-07-31T00:00:00", "1819-08-31T00:00:00", "1819-09-30T00:00:00", "1819-10-31T00:00:00", "1819-11-30T00:00:00", "1819-12-31T00:00:00", "1820-01-31T00:00:00", "1820-02-29T00:00:00", "1820-03-31T00:00:00", "1820-04-30T00:00:00", "1820-05-31T00:00:00", "1820-06-30T00:00:00", "1820-07-31T00:00:00", "1820-08-31T00:00:00", "1820-09-30T00:00:00", "1820-10-31T00:00:00", "1820-11-30T00:00:00", "1820-12-31T00:00:00", "1821-01-31T00:00:00", "1821-02-28T00:00:00", "1821-03-31T00:00:00", "1821-04-30T00:00:00", "1821-05-31T00:00:00", "1821-06-30T00:00:00", "1821-07-31T00:00:00", "1821-08-31T00:00:00", "1821-09-30T00:00:00", "1821-10-31T00:00:00", "1821-11-30T00:00:00", "1821-12-31T00:00:00", "1822-01-31T00:00:00", "1822-02-28T00:00:00", "1822-03-31T00:00:00", "1822-04-30T00:00:00", "1822
# %% [markdown]
# ## 3. Model

# %% [markdown]
# Define the forecasting horizon.

# %%
forecast_period = 12 * 10

# %% [markdown]
# Define a function for generating the forecasts and backcasts based on a set of hyperparameters.

# %%
def nn(target, forecast_period, params):
    
    '''
    Parameters:
    _______________________________
    target: np.array, pd.Series, list.
        Time series.
        
    forecast_period: int.
        Forecasting horizon.
    
    params: dict.
        Model parameters.
    
    Returns:
    _______________________________
    results: pd.DataFrame
        Forecast and backcast.
    '''

    tf.random.set_seed(TENSORFLOW_SEED)

    model = NBeats(
        target,
        forecast_period=forecast_period,
        lookback_period=params['multiplier'] * forecast_period,
        stacks=['trend', 'seasonality'],
        num_trend_coefficients=params['num_trend_coefficients'],
        num_seasonal_coefficients=params['num_seasonal_coefficients'],
        hidden_units=params['hidden_units'],
        num_blocks_per_stack=params['num_blocks_per_stack'],
        share_weights=params['share_weights'],
        share_coefficients=params['share_coefficients'],
    )

    model.fit(
        learning_rate=params['learning_rate'],
        batch_size=params['batch_size'],
        epochs=params['epochs'],
        backcast_loss_weight=params['backcast_loss_weight'],
        loss='mae',
        validation_split=0,
        verbose=False
    )

    results = model.forecast(return_backcast=True)

    return results

# %% [markdown]
# Tune the hyperparameters.

# %%
# Split the data into training and validation, set aside the last sequence for testing.
y_train = df['y'].iloc[: - 2 * forecast_period]
y_valid = df['y'].iloc[- 2 * forecast_period: - forecast_period] 

# Define the objective function.
def objective(trial):

    # Sample the hyperparameters.
    params = {
        'multiplier': trial.suggest_int('multiplier', 2, 7),
        'num_trend_coefficients': trial.suggest_int('num_trend_coefficients', 2, 4),
        'num_seasonal_coefficients': trial.suggest_int('num_seasonal_coefficients', 2, 8),
        'hidden_units': trial.suggest_int('hidden_units', 10, 100, step=10),
        'num_blocks_per_stack': trial.suggest_int('num_blocks_per_stack', 1, 3),
        'share_weights': trial.suggest_categorical('share_weights', [True, False]),
        'share_coefficients': trial.suggest_categorical('share_coefficients', [True, False]),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.01),
        'batch_size': trial.suggest_categorical('batch_size', [32, 64, 128, 256]),
        'epochs': trial.suggest_int('epochs', 100, 300, step=100),
        'backcast_loss_weight': trial.suggest_float('backcast_loss_weight', 0, 0.5, step=0.1),   
    }

    # Generate the forecast and backcast.
    df_pred = nn(
        target=y_train, 
        forecast_period=forecast_period, 
        params=params
    ) 

    # Extract the forecast.
    y_pred = df_pred['forecast'].iloc[- forecast_period:].values

    # Calculate the forecasting error.
    return np.mean(np.abs(y_valid - y_pred))

# Minimize the objective function.
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.RandomSampler(OPTUNA_SEED))
study.optimize(objective, n_trials=50)

# Extract the best parameters.
best_params = study.best_params
# Out:
# [I 2021-11-12 19:33:43,848] A new study created in memory with name: no-name-84043c73-5376-41d3-8d93-8ae7457ed78a
# [I 2021-11-12 19:34:02,802] Trial 0 finished with value: 57.893862913555246 and parameters: {'multiplier': 5, 'num_trend_coefficients': 4, 'num_seasonal_coefficients': 6, 'hidden_units': 60, 'num_blocks_per_stack': 2, 'share_weights': True, 'share_coefficients': False, 'learning_rate': 0.0024179177243329477, 'batch_size': 256, 'epochs': 100, 'backcast_loss_weight': 0.0}. Best is trial 0 with value: 57.893862913555246.
# [I 2021-11-12 19:34:42,980] Trial 1 finished with value: 32.85572568821898 and parameters: {'multiplier': 2, 'num_trend_coefficients': 4, 'num_seasonal_coefficients': 7, 'hidden_units': 90, 'num_blocks_per_stack': 3, 'share_weights': True, 'share_coefficients': True, 'learning_rate': 0.00436436456821403, 'batch_size': 64, 'epochs': 100, 'backcast_loss_weight': 0.4}. Best is trial 1 with value: 32.85572568821898.
# [I 2021-11-12 19:35:24,749] Trial 2 finished with value: 45.72229097535356 and parameters: {'multiplier': 4, 'num_trend_coefficients': 3, 'num_seasonal_coefficients': 2, 'hidden_units': 70, 'num_blocks_per_stack': 2, 'share_weights': False, 'share_coefficients': True, 'learning_rate': 0.0027354699847778976, 'batch_size': 32, 'epochs': 100, 'backcast_loss_weight': 0.0}. Best is trial 1 with value: 32.85572568821898.
# [I 2021-11-12 19:37:18,795] Trial 3 finished with value: 34.47324443135522 and parameters: {'multiplier': 3, 'num_trend_coefficients': 3, 'num_seasonal_coefficients': 5, 'hidden_units': 50, 'num_blocks_per_stack': 3, 'share_weights': False, 'share_coefficients': False, 'learning_rate': 0.0017918085415441003, 'batch_size': 32, 'epochs': 200, 'backcast_loss_weight': 0.0}. Best is trial 1 with value: 32.85572568821898.
# [I 2021-11-12 19:38:16,862] Trial 4 finished with value: 38.487355284367396 and parameters: {'multiplier': 3, 'num_trend_coefficients': 3, 'num_seasonal_coefficients': 7, 'hidden_units': 10, 'num_blocks_per_stack': 3, 'share_weights': False, 'share_coefficients': False, 'learning_rate': 0.004025738117667019, 'batch_size': 32, 'epochs': 100, 'backcast_loss_weight': 0.0}. Best is trial 1 with value: 32.85572568821898.
# [I 2021-11-12 19:38:33,908] Trial 5 finished with value: 35.33616268303055 and parameters: {'multiplier': 3, 'num_trend_coefficients': 3, 'num_seasonal_coefficients': 2, 'hidden_units': 70, 'num_blocks_per_stack': 2, 'share_weights': False, 'share_coefficients': False, 'learning_rate': 0.008497598307525042, 'batch_size': 256, 'epochs': 100, 'backcast_loss_weight': 0.1}. Best is trial 1 with value: 32.85572568821898.
# [I 2021-11-12 19:39:04,660] Trial 6 finished with value: 62.62621094237398 and parameters: {'multiplier': 5, 'num_trend_coefficients': 2, 'num_seasonal_coefficients': 7, 'hidden_units': 10, 'num_blocks_per_stack': 3, 'share_weights': False, 'share_coefficients': True, 'learning_rate': 0.003768402944091238, 'batch_size': 256, 'epochs': 200, 'backcast_loss_weight': 0.5}. Best is trial 1 with value: 32.85572568821898.
# [I 2021-11-12 19:39:58,186] Trial 7 finished with value: 39.11989452332828 and parameters: {'multiplier': 6, 'num_trend_coefficients': 2, 'num_seasonal_coefficients': 7, 'hidden_units': 40, 'num_blocks_per_stack': 3, 'share_weights': False, 'share_coefficients': False, 'learning_rate': 0.0031719357511761997, 'batch_size': 32, 'epochs': 100, 'backcast_loss_weight': 0.1}. Best is trial 1 with value: 32.85572568821898.
# [I 2021-11-12 19:40:18,517] Trial 8 finished with value: 25.19190248409364 and parameters: {'multiplier': 5, 'num_trend_coefficients': 2, 'num_seasonal_coefficients': 6, 'hidden_units': 50, 'num_blocks_per_stack': 1, 'share_weights': False, 'share_coefficients': True, 'learning_rate': 0.0044998788335434145, 'batch_size': 128, 'epochs': 200, 'backcast_loss_weight': 0.5}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 19:41:35,160] Trial 9 finished with value: 67.2729508010785 and parameters: {'multiplier': 6, 'num_trend_coefficients': 4, 'num_seasonal_coefficients': 2, 'hidden_units': 100, 'num_blocks_per_stack': 3, 'share_weights': True, 'share_coefficients': True, 'learning_rate': 0.004126288260354439, 'batch_size': 64, 'epochs': 200, 'backcast_loss_weight': 0.0}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 19:44:28,340] Trial 10 finished with value: 37.40019766081502 and parameters: {'multiplier': 6, 'num_trend_coefficients': 3, 'num_seasonal_coefficients': 7, 'hidden_units': 90, 'num_blocks_per_stack': 3, 'share_weights': True, 'share_coefficients': False, 'learning_rate': 0.0014846691255892349, 'batch_size': 32, 'epochs': 300, 'backcast_loss_weight': 0.1}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 19:44:44,970] Trial 11 finished with value: 37.7499199440955 and parameters: {'multiplier': 4, 'num_trend_coefficients': 4, 'num_seasonal_coefficients': 6, 'hidden_units': 10, 'num_blocks_per_stack': 1, 'share_weights': True, 'share_coefficients': False, 'learning_rate': 0.004111174926348789, 'batch_size': 128, 'epochs': 200, 'backcast_loss_weight': 0.1}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 19:46:01,204] Trial 12 finished with value: 43.048597962037505 and parameters: {'multiplier': 3, 'num_trend_coefficients': 4, 'num_seasonal_coefficients': 7, 'hidden_units': 50, 'num_blocks_per_stack': 1, 'share_weights': True, 'share_coefficients': True, 'learning_rate': 0.004969852377494225, 'batch_size': 32, 'epochs': 300, 'backcast_loss_weight': 0.2}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 19:46:16,032] Trial 13 finished with value: 45.348850785484125 and parameters: {'multiplier': 5, 'num_trend_coefficients': 4, 'num_seasonal_coefficients': 8, 'hidden_units': 30, 'num_blocks_per_stack': 2, 'share_weights': True, 'share_coefficients': True, 'learning_rate': 0.0024180423014158762, 'batch_size': 256, 'epochs': 100, 'backcast_loss_weight': 0.4}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 19:46:35,867] Trial 14 finished with value: 42.894547976237156 and parameters: {'multiplier': 3, 'num_trend_coefficients': 4, 'num_seasonal_coefficients': 6, 'hidden_units': 30, 'num_blocks_per_stack': 3, 'share_weights': True, 'share_coefficients': False, 'learning_rate': 0.001060871342884135, 'batch_size': 256, 'epochs': 100, 'backcast_loss_weight': 0.30000000000000004}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 19:47:46,623] Trial 15 finished with value: 47.14699420760064 and parameters: {'multiplier': 7, 'num_trend_coefficients': 2, 'num_seasonal_coefficients': 5, 'hidden_units': 20, 'num_blocks_per_stack': 3, 'share_weights': False, 'share_coefficients': True, 'learning_rate': 0.0030764954749825076, 'batch_size': 64, 'epochs': 300, 'backcast_loss_weight': 0.0}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 19:48:27,749] Trial 16 finished with value: 56.19377151974184 and parameters: {'multiplier': 5, 'num_trend_coefficients': 3, 'num_seasonal_coefficients': 8, 'hidden_units': 30, 'num_blocks_per_stack': 1, 'share_weights': True, 'share_coefficients': True, 'learning_rate': 0.006097515486678242, 'batch_size': 64, 'epochs': 300, 'backcast_loss_weight': 0.5}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 19:51:16,401] Trial 17 finished with value: 42.655613880973284 and parameters: {'multiplier': 4, 'num_trend_coefficients': 4, 'num_seasonal_coefficients': 3, 'hidden_units': 100, 'num_blocks_per_stack': 3, 'share_weights': True, 'share_coefficients': True, 'learning_rate': 0.007062257610573921, 'batch_size': 32, 'epochs': 300, 'backcast_loss_weight': 0.2}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 19:52:01,901] Trial 18 finished with value: 35.141019520967795 and parameters: {'multiplier': 4, 'num_trend_coefficients': 3, 'num_seasonal_coefficients': 4, 'hidden_units': 20, 'num_blocks_per_stack': 3, 'share_weights': False, 'share_coefficients': True, 'learning_rate': 0.007281008154058432, 'batch_size': 32, 'epochs': 100, 'backcast_loss_weight': 0.0}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 19:53:58,030] Trial 19 finished with value: 48.56415770540988 and parameters: {'multiplier': 4, 'num_trend_coefficients': 2, 'num_seasonal_coefficients': 2, 'hidden_units': 10, 'num_blocks_per_stack': 3, 'share_weights': False, 'share_coefficients': True, 'learning_rate': 0.0012291447605638352, 'batch_size': 32, 'epochs': 300, 'backcast_loss_weight': 0.4}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 19:54:34,345] Trial 20 finished with value: 52.64444141716116 and parameters: {'multiplier': 3, 'num_trend_coefficients': 2, 'num_seasonal_coefficients': 2, 'hidden_units': 40, 'num_blocks_per_stack': 1, 'share_weights': False, 'share_coefficients': True, 'learning_rate': 0.0023984294926250507, 'batch_size': 64, 'epochs': 300, 'backcast_loss_weight': 0.4}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 19:54:57,780] Trial 21 finished with value: 33.34801504861809 and parameters: {'multiplier': 3, 'num_trend_coefficients': 3, 'num_seasonal_coefficients': 6, 'hidden_units': 30, 'num_blocks_per_stack': 2, 'share_weights': False, 'share_coefficients': False, 'learning_rate': 0.0011938683719448858, 'batch_size': 256, 'epochs': 200, 'backcast_loss_weight': 0.0}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 19:55:28,324] Trial 22 finished with value: 43.88994335819199 and parameters: {'multiplier': 4, 'num_trend_coefficients': 3, 'num_seasonal_coefficients': 5, 'hidden_units': 70, 'num_blocks_per_stack': 1, 'share_weights': False, 'share_coefficients': True, 'learning_rate': 0.008016484458240575, 'batch_size': 128, 'epochs': 300, 'backcast_loss_weight': 0.2}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 19:56:34,052] Trial 23 finished with value: 42.50553093262292 and parameters: {'multiplier': 7, 'num_trend_coefficients': 4, 'num_seasonal_coefficients': 6, 'hidden_units': 40, 'num_blocks_per_stack': 3, 'share_weights': True, 'share_coefficients': False, 'learning_rate': 0.00910262398398695, 'batch_size': 128, 'epochs': 300, 'backcast_loss_weight': 0.30000000000000004}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 19:56:56,036] Trial 24 finished with value: 54.981866739696585 and parameters: {'multiplier': 6, 'num_trend_coefficients': 4, 'num_seasonal_coefficients': 7, 'hidden_units': 20, 'num_blocks_per_stack': 2, 'share_weights': True, 'share_coefficients': True, 'learning_rate': 0.007063798601638292, 'batch_size': 64, 'epochs': 100, 'backcast_loss_weight': 0.1}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 19:57:39,843] Trial 25 finished with value: 33.906026610962236 and parameters: {'multiplier': 4, 'num_trend_coefficients': 4, 'num_seasonal_coefficients': 2, 'hidden_units': 100, 'num_blocks_per_stack': 3, 'share_weights': True, 'share_coefficients': False, 'learning_rate': 0.0010791320507180368, 'batch_size': 64, 'epochs': 100, 'backcast_loss_weight': 0.1}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 19:58:31,834] Trial 26 finished with value: 34.840111138900674 and parameters: {'multiplier': 2, 'num_trend_coefficients': 2, 'num_seasonal_coefficients': 2, 'hidden_units': 70, 'num_blocks_per_stack': 3, 'share_weights': True, 'share_coefficients': False, 'learning_rate': 0.00309246894123184, 'batch_size': 32, 'epochs': 100, 'backcast_loss_weight': 0.30000000000000004}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 20:00:30,112] Trial 27 finished with value: 48.94572451415766 and parameters: {'multiplier': 3, 'num_trend_coefficients': 3, 'num_seasonal_coefficients': 5, 'hidden_units': 50, 'num_blocks_per_stack': 2, 'share_weights': False, 'share_coefficients': True, 'learning_rate': 0.006739953721554801, 'batch_size': 32, 'epochs': 300, 'backcast_loss_weight': 0.5}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 20:01:07,480] Trial 28 finished with value: 30.97136167781212 and parameters: {'multiplier': 7, 'num_trend_coefficients': 4, 'num_seasonal_coefficients': 4, 'hidden_units': 100, 'num_blocks_per_stack': 1, 'share_weights': False, 'share_coefficients': False, 'learning_rate': 0.0011438165048911892, 'batch_size': 64, 'epochs': 200, 'backcast_loss_weight': 0.4}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 20:01:53,427] Trial 29 finished with value: 34.765962666264 and parameters: {'multiplier': 3, 'num_trend_coefficients': 2, 'num_seasonal_coefficients': 5, 'hidden_units': 40, 'num_blocks_per_stack': 3, 'share_weights': False, 'share_coefficients': True, 'learning_rate': 0.007366978551960061, 'batch_size': 256, 'epochs': 300, 'backcast_loss_weight': 0.2}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 20:02:12,703] Trial 30 finished with value: 39.98362139275579 and parameters: {'multiplier': 2, 'num_trend_coefficients': 2, 'num_seasonal_coefficients': 3, 'hidden_units': 50, 'num_blocks_per_stack': 1, 'share_weights': True, 'share_coefficients': False, 'learning_rate': 0.0035227749678413715, 'batch_size': 128, 'epochs': 200, 'backcast_loss_weight': 0.1}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 20:02:38,712] Trial 31 finished with value: 48.20270802097967 and parameters: {'multiplier': 4, 'num_trend_coefficients': 3, 'num_seasonal_coefficients': 3, 'hidden_units': 60, 'num_blocks_per_stack': 1, 'share_weights': False, 'share_coefficients': True, 'learning_rate': 0.008397669270755255, 'batch_size': 32, 'epochs': 100, 'backcast_loss_weight': 0.2}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 20:03:11,042] Trial 32 finished with value: 48.76959455285053 and parameters: {'multiplier': 6, 'num_trend_coefficients': 4, 'num_seasonal_coefficients': 6, 'hidden_units': 80, 'num_blocks_per_stack': 1, 'share_weights': False, 'share_coefficients': True, 'learning_rate': 0.0019173422878975398, 'batch_size': 64, 'epochs': 200, 'backcast_loss_weight': 0.5}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 20:03:49,286] Trial 33 finished with value: 36.58861362352843 and parameters: {'multiplier': 2, 'num_trend_coefficients': 3, 'num_seasonal_coefficients': 2, 'hidden_units': 40, 'num_blocks_per_stack': 2, 'share_weights': True, 'share_coefficients': False, 'learning_rate': 0.004957583136932003, 'batch_size': 64, 'epochs': 200, 'backcast_loss_weight': 0.30000000000000004}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 20:05:26,776] Trial 34 finished with value: 41.75801173550564 and parameters: {'multiplier': 7, 'num_trend_coefficients': 2, 'num_seasonal_coefficients': 6, 'hidden_units': 90, 'num_blocks_per_stack': 2, 'share_weights': False, 'share_coefficients': False, 'learning_rate': 0.003310948111038919, 'batch_size': 32, 'epochs': 200, 'backcast_loss_weight': 0.5}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 20:07:41,275] Trial 35 finished with value: 26.730333061512532 and parameters: {'multiplier': 5, 'num_trend_coefficients': 2, 'num_seasonal_coefficients': 8, 'hidden_units': 90, 'num_blocks_per_stack': 2, 'share_weights': True, 'share_coefficients': True, 'learning_rate': 0.009295792273745138, 'batch_size': 32, 'epochs': 300, 'backcast_loss_weight': 0.1}. Best is trial 8 with value: 25.19190248409364.
# [I 2021-11-12 20:08:08,539] Trial 36 finished with value: 18.599988375235363 and parameters: {'multiplier': 2, 'num_trend_coefficients': 4, 'num_seasonal_coefficients': 5, 'hidden_units': 100, 'num_blocks_per_stack': 1, 'share_weights': True, 'share_coefficients': False, 'learning_rate': 0.0017676600857316625, 'batch_size': 256, 'epochs': 300, 'backcast_loss_weight': 0.5}. Best is trial 36 with value: 18.599988375235363.
# [I 2021-11-12 20:08:54,288] Trial 37 finished with value: 75.54627724912739 and parameters: {'multiplier': 6, 'num_trend_coefficients': 3, 'num_seasonal_coefficients': 4, 'hidden_units': 100, 'num_blocks_per_stack': 2, 'share_weights': True, 'share_coefficients': True, 'learning_rate': 0.002128080248589846, 'batch_size': 32, 'epochs': 100, 'backcast_loss_weight': 0.1}. Best is trial 36 with value: 18.599988375235363.
# [I 2021-11-12 20:09:47,306] Trial 38 finished with value: 32.047829572909755 and parameters: {'multiplier': 5, 'num_trend_coefficients': 3, 'num_seasonal_coefficients': 5, 'hidden_units': 40, 'num_blocks_per_stack': 3, 'share_weights': True, 'share_coefficients': False, 'learning_rate': 0.004562222603075258, 'batch_size': 64, 'epochs': 200, 'backcast_loss_weight': 0.4}. Best is trial 36 with value: 18.599988375235363.
# [I 2021-11-12 20:10:41,879] Trial 39 finished with value: 38.35445721795793 and parameters: {'multiplier': 7, 'num_trend_coefficients': 4, 'num_seasonal_coefficients': 7, 'hidden_units': 70, 'num_blocks_per_stack': 2, 'share_weights': True, 'share_coefficients': False, 'learning_rate': 0.0033265669899278975, 'batch_size': 64, 'epochs': 200, 'backcast_loss_weight': 0.4}. Best is trial 36 with value: 18.599988375235363.
# [I 2021-11-12 20:11:48,775] Trial 40 finished with value: 45.40401201488974 and parameters: {'multiplier': 7, 'num_trend_coefficients': 4, 'num_seasonal_coefficients': 8, 'hidden_units': 40, 'num_blocks_per_stack': 2, 'share_weights': False, 'share_coefficients': False, 'learning_rate': 0.0012510019734387197, 'batch_size': 64, 'epochs': 300, 'backcast_loss_weight': 0.0}. Best is trial 36 with value: 18.599988375235363.
# [I 2021-11-12 20:12:32,606] Trial 41 finished with value: 35.2923996580197 and parameters: {'multiplier': 4, 'num_trend_coefficients': 2, 'num_seasonal_coefficients': 5, 'hidden_units': 100, 'num_blocks_per_stack': 2, 'share_weights': True, 'share_coefficients': False, 'learning_rate': 0.002510800115803857, 'batch_size': 128, 'epochs': 200, 'backcast_loss_weight': 0.2}. Best is trial 36 with value: 18.599988375235363.
# [I 2021-11-12 20:14:18,054] Trial 42 finished with value: 28.652947707316052 and parameters: {'multiplier': 5, 'num_trend_coefficients': 2, 'num_seasonal_coefficients': 7, 'hidden_units': 70, 'num_blocks_per_stack': 3, 'share_weights': True, 'share_coefficients': False, 'learning_rate': 0.0020943197586019823, 'batch_size': 64, 'epochs': 300, 'backcast_loss_weight': 0.30000000000000004}. Best is trial 36 with value: 18.599988375235363.
# [I 2021-11-12 20:14:39,765] Trial 43 finished with value: 67.67023557955038 and parameters: {'multiplier': 7, 'num_trend_coefficients': 2, 'num_seasonal_coefficients': 8, 'hidden_units': 10, 'num_blocks_per_stack': 2, 'share_weights': False, 'share_coefficients': True, 'learning_rate': 0.0010450158978976157, 'batch_size': 64, 'epochs': 100, 'backcast_loss_weight': 0.0}. Best is trial 36 with value: 18.599988375235363.
# [I 2021-11-12 20:14:51,034] Trial 44 finished with value: 33.362773897471506 and parameters: {'multiplier': 3, 'num_trend_coefficients': 2, 'num_seasonal_coefficients': 3, 'hidden_units': 10, 'num_blocks_per_stack': 1, 'share_weights': True, 'share_coefficients': False, 'learning_rate': 0.0028602866910953295, 'batch_size': 256, 'epochs': 200, 'backcast_loss_weight': 0.4}. Best is trial 36 with value: 18.599988375235363.
# [I 2021-11-12 20:16:05,120] Trial 45 finished with value: 67.25887523876753 and parameters: {'multiplier': 6, 'num_trend_coefficients': 4, 'num_seasonal_coefficients': 2, 'hidden_units': 90, 'num_blocks_per_stack': 2, 'share_weights': True, 'share_coefficients': True, 'learning_rate': 0.002314966048489277, 'batch_size': 32, 'epochs': 200, 'backcast_loss_weight': 0.4}. Best is trial 36 with value: 18.599988375235363.
# [I 2021-11-12 20:16:14,059] Trial 46 finished with value: 33.429813591175986 and parameters: {'multiplier': 3, 'num_trend_coefficients': 3, 'num_seasonal_coefficients': 2, 'hidden_units': 20, 'num_blocks_per_stack': 1, 'share_weights': True, 'share_coefficients': False, 'learning_rate': 0.0012060619019958743, 'batch_size': 128, 'epochs': 100, 'backcast_loss_weight': 0.30000000000000004}. Best is trial 36 with value: 18.599988375235363.
# [I 2021-11-12 20:17:01,409] Trial 47 finished with value: 43.74586252358107 and parameters: {'multiplier': 7, 'num_trend_coefficients': 3, 'num_seasonal_coefficients': 3, 'hidden_units': 90, 'num_blocks_per_stack': 2, 'share_weights': False, 'share_coefficients': False, 'learning_rate': 0.0028741085528027326, 'batch_size': 256, 'epochs': 300, 'backcast_loss_weight': 0.2}. Best is trial 36 with value: 18.599988375235363.
# [I 2021-11-12 20:17:37,594] Trial 48 finished with value: 25.380659721456247 and parameters: {'multiplier': 7, 'num_trend_coefficients': 4, 'num_seasonal_coefficients': 6, 'hidden_units': 30, 'num_blocks_per_stack': 1, 'share_weights': False, 'share_coefficients': False, 'learning_rate': 0.00311858678320773, 'batch_size': 64, 'epochs': 300, 'backcast_loss_weight': 0.4}. Best is trial 36 with value: 18.599988375235363.
# [I 2021-11-12 20:18:14,736] Trial 49 finished with value: 52.234381868257614 and parameters: {'multiplier': 2, 'num_trend_coefficients': 2, 'num_seasonal_coefficients': 4, 'hidden_units': 10, 'num_blocks_per_stack': 2, 'share_weights': False, 'share_coefficients': False, 'learning_rate': 0.0013107674343020169, 'batch_size': 32, 'epochs': 100, 'backcast_loss_weight': 0.2}. Best is trial 36 with value: 18.599988375235363.

# %%
best_params
# Out:
# {'backcast_loss_weight': 0.5,
#  'batch_size': 256,
#  'epochs': 300,
#  'hidden_units': 100,
#  'learning_rate': 0.0017676600857316625,
#  'multiplier': 2,
#  'num_blocks_per_stack': 1,
#  'num_seasonal_coefficients': 5,
#  'num_trend_coefficients': 4,
#  'share_coefficients': False,
#  'share_weights': True}

# %% [markdown]
# Generate the test set predictions.

# %%
df_test = nn(
    target=df['y'].iloc[: - forecast_period], 
    forecast_period=forecast_period, 
    params=best_params
)

# %% [markdown]
# Add the timestamps to the output data frame.

# %%
df_test['time_idx'] = df['timestamp']

# %%
df_test.iloc[- 2 * forecast_period:]
# Out:
#        time_idx      actual  forecast    backcast
# 2206 2001-11-30  176.566667       NaN  176.902740
# 2207 2001-12-31  213.419355       NaN  213.749298
# 2208 2002-01-31  184.645161       NaN  184.968475
# 2209 2002-02-28  170.178571       NaN  170.494781
# 2210 2002-03-31  147.096774       NaN  147.405319
# ...         ...         ...       ...         ...
# 2441 2021-06-30         NaN  0.308618         NaN
# 2442 2021-07-31         NaN  1.049440         NaN
# 2443 2021-08-31         NaN  1.885758         NaN
# 2444 2021-09-30         NaN  2.817844         NaN
# 2445 2021-10-31         NaN  3.845694         NaN
#
# [240 rows x 4 columns]

# %% [markdown]
# Plot the test set predictions.

# %%
layout = dict(
    width=800,
    height=425,
    plot_bgcolor='white',
    paper_bgcolor='white',
    margin=dict(t=40, b=20, l=20, r=20),
    legend=dict(
        font=dict(
            color='#3a3a3a',
            size=10,
        ),
        orientation='h',
        x=0.0,
        y=1.1,
    ),
    xaxis=dict(
        type='date',
        nticks=20,
        tickfont=dict(
            color='#3a3a3a',
            size=10,
        ),
        linecolor='#d9d9d9',
        mirror=True,
        showgrid=False,
    ),
    yaxis=dict(
        tickfont=dict(
            color='#3a3a3a',
            size=10,
        ),
        linecolor='#d9d9d9',
        mirror=True,
        showgrid=False,
        zeroline=False,
    ),
)

data = []

data.append(
    go.Scatter(
        x=df['timestamp'],
        y=df['y'],
        name='Actual',
        mode='lines',
        line=dict(
            color='#b3b3b3',
            width=0.5
        )
    )
)

data.append(
    go.Scatter(
        x=df_test['time_idx'],
        y=df_test['forecast'],
        name='Forecast',
        mode='lines',
        line=dict(
            color='#0550ae',
            width=1
          )
      )
)

data.append(
    go.Scatter(
        x=df_test['time_idx'],
        y=df_test['backcast'],
        name='Backcast',
        mode='lines',
        line=dict(
            color='#8250df',
            width=1
        )
    )
)

fig = go.Figure(data=data, layout=layout)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="032fed60-a332-4ac8-98f1-d50d410132a3" class="plotly-graph-div" style="height:425px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById
00:00", "1827-04-30T00:00:00", "1827-05-31T00:00:00", "1827-06-30T00:00:00", "1827-07-31T00:00:00", "1827-08-31T00:00:00", "1827-09-30T00:00:00", "1827-10-31T00:00:00", "1827-11-30T00:00:00", "1827-12-31T00:00:00", "1828-01-31T00:00:00", "1828-02-29T00:00:00", "1828-03-31T00:00:00", "1828-04-30T00:00:00", "1828-05-31T00:00:00", "1828-06-30T00:00:00", "1828-07-31T00:00:00", "1828-08-31T00:00:00", "1828-09-30T00:00:00", "1828-10-31T00:00:00", "1828-11-30T00:00:00", "1828-12-31T00:00:00", "1829-01-31T00:00:00", "1829-02-28T00:00:00", "1829-03-31T00:00:00", "1829-04-30T00:00:00", "1829-05-31T00:00:00", "1829-06-30T00:00:00", "1829-07-31T00:00:00", "1829-08-31T00:00:00", "1829-09-30T00:00:00", "1829-10-31T00:00:00", "1829-11-30T00:00:00", "1829-12-31T00:00:00", "1830-01-31T00:00:00", "1830-02-28T00:00:00", "1830-03-31T00:00:00", "1830-04-30T00:00:00", "1830-05-31T00:00:00", "1830-06-30T00:00:00", "1830-07-31T00:00:00", "1830-08-31T00:00:00", "1830-09-30T00:00:00", "1830-10-31T00:00:00", "1830-11-30T00:00:00", "1830-12-31T00:00:00", "1831-01-31T00:00:00", "1831-02-28T00:00:00", "1831-03-31T00:00:00", "1831-04-30T00:00:00", "1831-05-31T00:00:00", "1831-06-30T00:00:00", "1831-07-31T00:00:00", "1831-08-31T00:00:00", "1831-09-30T00:00:00", "1831-10-31T00:00:00", "1831-11-30T00:00:00", "1831-12-31T00:00:00", "1832- ...

# %% [markdown]
# ## 4. Results

# %% [markdown]
# Fit the model using all the data.

# %%
df_future = nn(
    target=df['y'], 
    forecast_period=forecast_period, 
    params=best_params
)

# %% [markdown]
# Add the timestamps to the output data frame.

# %%
df_future['time_idx'].iloc[:- forecast_period] = df['timestamp']
df_future['time_idx'].iloc[- forecast_period:] = pd.date_range(start=df['timestamp'].iloc[-1], periods=1 + forecast_period, freq='M')[1:]

# %%
df_future.iloc[- 2 * forecast_period:]
# Out:
#                  time_idx      actual  forecast    backcast
# 2326  2011-11-30 00:00:00  139.066667       NaN  138.281693
# 2327  2011-12-31 00:00:00  109.290323       NaN  108.514587
# 2328  2012-01-31 00:00:00   94.419355       NaN   93.652260
# 2329  2012-02-29 00:00:00   47.758621       NaN   46.999592
# 2330  2012-03-31 00:00:00   86.645161       NaN   85.893631
# ...                   ...         ...       ...         ...
# 2561  2031-06-30 00:00:00         NaN  1.436062         NaN
# 2562  2031-07-31 00:00:00         NaN  0.953183         NaN
# 2563  2031-08-31 00:00:00         NaN  0.534907         NaN
# 2564  2031-09-30 00:00:00         NaN  0.186163         NaN
# 2565  2031-10-31 00:00:00         NaN -0.088199         NaN
#
# [240 rows x 4 columns]

# %% [markdown]
# Plot the out of sample forecasts.

# %%
layout = dict(
    width=800,
    height=425,
    plot_bgcolor='white',
    paper_bgcolor='white',
    margin=dict(t=40, b=20, l=20, r=20),
    legend=dict(
        font=dict(
            color='#3a3a3a',
            size=10,
        ),
        orientation='h',
        x=0.0,
        y=1.1,
    ),
    xaxis=dict(
        type='date',
        nticks=20,
        tickfont=dict(
            color='#3a3a3a',
            size=10,
        ),
        linecolor='#d9d9d9',
        mirror=True,
        showgrid=False,
    ),
    yaxis=dict(
        tickfont=dict(
            color='#3a3a3a',
            size=10,
        ),
        linecolor='#d9d9d9',
        mirror=True,
        showgrid=False,
        zeroline=False,
    ),
)

data = []

data.append(
    go.Scatter(
        x=df['timestamp'],
        y=df['y'],
        name='Actual',
        mode='lines',
        line=dict(
            color='#b3b3b3',
            width=0.5
        )
    )
)

data.append(
    go.Scatter(
        x=df_future['time_idx'],
        y=df_future['forecast'],
        name='Forecast',
        mode='lines',
        line=dict(
            color='#0550ae',
            width=1
          )
      )
)

data.append(
    go.Scatter(
        x=df_future['time_idx'],
        y=df_future['backcast'],
        name='Backcast',
        mode='lines',
        line=dict(
            color='#8250df',
            width=1
        )
    )
)

fig = go.Figure(data=data, layout=layout)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6c59ad9f-cc25-4db8-b394-5717a5ba3d38" class="plotly-graph-div" style="height:425px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6c59ad9f-cc25-4db8-b394-5717a5ba3d38")) {
#                     Plotly.newPlot(
#                         '6c59ad9f-cc25-4db8-b394-5717a5ba3d38',
#                         [{"line": {"color": "#b3b3b3", "width": 0.5}, "mode": "lines", "name": "Actual", "type": "scatter", "x": ["1818-01-31T00:00:00", "1818-02-28T00:00:00", "1818-03-31T00:00:00", "1818-04-30T00:00:00", "1818-05-31T00:00:00", "1818-06-30T00:00:00", "1818-07-31T00:00:00", "1818-08-31T00:00:00", "1818-09-30T00:00:00", "1818-10-31T00:00:00", "1818-11-30T00:00:00", "1818-12-31T00:00:00", "1819-01-31T00:00:00", "1819-02-28T00:00:00", "1819-03-31T00:00:00", "1819-04-30T00:00:00", "1819-05-31T00:00:00", "1819-06-30T00:00:00", "1819-07-31T00:00:00", "1819-08-31T00:00:00", "1819-09-30T00:00:00", "1819-10-31T00:00:00", "1819-11-30T00:00:00", "1819-12-31T00:00:00", "1820-01-31T00:00:00", "1820-02-29T00:00:00", "1820-03-31T00:00:00", "1820-04-30T00:00:00", "1820-05-31T00:00:00", "1820-06-30T00:00:00", "1820-07-31T00:00:00", "1820-08-31T00:00:00", "1820-09-30T00:00:00", "1820-10-31T00:00:00", "1820-11-30T00:00:00", "1820-12-31T00:00:00", "1821-01-31T00:00:00", "1821-02-28T00:00:00", "1821-03-31T00:00:00", "1821-04-30T00:00:00", "1821-05-31T00:00:00", "1821-06-30T00:00:00", "1821-07-31T00:00:00", "1821-08-31T00:00:00", "1821-09-30T00:00:00", "1821-10-31T00:00:00", "1821-11-30T00:00:00", "1821-12-31T00:00:00", "1822-01-31T00:00:00", "1822-02-28T00:00:00", "1822-03-31T00:00:00", "1822-04-30T00:00:00", "1822-05-31T00:00:00", "1822-06-30T00:00:00", "1822-07-31T00:00:00", "1822-08-31T00:00:00", "1822-09-30T00:00:00", "1822-10-31T00:00:00", "1822-11-30T00:00:00", "1822-12-31T00:00:00", "1823-01-31T00:00:00", "1